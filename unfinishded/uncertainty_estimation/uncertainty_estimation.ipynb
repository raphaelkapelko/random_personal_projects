# %%
import kagglehub
import pandas
import jax
import jax.numpy as jnp
import flax.linen as nn
import flax

# Download latest version
path = kagglehub.dataset_download("oddrationale/mnist-in-csv")
path_train = path + "/mnist_train.csv"
path_test = path + "/mnist_test.csv"

# %%
train_df = pandas.read_csv(path_train).to_numpy()
test_df = pandas.read_csv(path_test).to_numpy()
X_train = train_df[:, 0]
Y_train = train_df[:, 1:]
X_test = test_df[:, 0]
Y_test = test_df[:, 1:]

print(X_train)
print(Y_train)
print(X_test)
print(Y_test)
